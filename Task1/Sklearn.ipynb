# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
from sklearn import linear_model
from sklearn.model_selection import train_test_split

# %%
# Import the Dataset 
df = pd.read_csv('/Users/rawanghanemhmx/Desktop/Task1/insurance.csv')

# %%
# Select the age column and the cost column
X = df[['bmi']]
y = df[['charges']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
# regressor = linear_model.LinearRegression()
# regressor.fit(x_train, y_train)

# r_squared = regressor.score(x_test,y_test)
# print(r_squared)

# predictions = regressor.predict(x_test)  # a list of all predictions

# for x in range(len(predictions)):
#     print(round(predictions[x]), y_test[x])

# %%
import numpy as np

import pandas as pd

import seaborn as sns

import matplotlib.pyplot as plt

from sklearn import preprocessing, svm

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('/Users/rawanghanemhmx/Desktop/Task1/insurance.csv')

# %%
df_binary = df[['bmi', 'charges']]

print(df_binary)
# Out:
#          bmi      charges
# 0     27.900  16884.92400
# 1     33.770   1725.55230
# 2     33.000   4449.46200
# 3     22.705  21984.47061
# 4     28.880   3866.85520
# ...      ...          ...
# 1333  30.970  10600.54830
# 1334  31.920   2205.98080
# 1335  36.850   1629.83350
# 1336  25.800   2007.94500
# 1337  29.070  29141.36030
#
# [1338 rows x 2 columns]

# %%
y_pred = regr.predict(X_test)
plt.figure(figsize=(10,5))
plt.scatter(X_test, y_test, color ='blue', label='Training data', s=200, linewidths=1, edgecolor='black')
plt.plot(X_test, y_pred, color ='red', label='Prediction line', linewidth=3)

plt.title('Medical costs billed by health insurance')
plt.xlabel('BMI')
plt.ylabel('Medical costs')

plt.legend()
plt.show()
